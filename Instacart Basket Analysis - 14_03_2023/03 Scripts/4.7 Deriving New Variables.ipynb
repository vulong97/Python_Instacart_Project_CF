# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Creating path shortcut
path = r'C:\Users\Longus\Documents\26-02-2023 Instacart Basket Analysis'

# %%
#Importing 'orders_products_merged.pkl'
df_ords_prods_merged = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
#Creating a subset to avoid RAM issues
df = df_ords_prods_merged[:1000000]

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                  0             0   2539329        1             1
# 1                  1             1   2398795        1             2
# 2                  2             2    473747        1             3
# 3                  3             3   2254736        1             4
# 4                  4             4    431534        1             5
# ...              ...           ...       ...      ...           ...
# 999995       2731921       2731921   2836489   164627            14
# 999996       2731962       2731962   1843600   164632             5
# 999997       2731966       2731966    733106   164632             9
# 999998       2731974       2731974   1650124   164632            17
# 999999       2731979       2731979   3378258   164632            22
#
#         order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# ...

# %% [markdown]
# ## If- statement with user-defined functions

# %%
#Defining the function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Longus\AppData\Local\Temp\ipykernel_22576\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#Checking maximum price in the subset 'df'
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## If- stament with loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Longus\AppData\Local\Temp\ipykernel_22576\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
#Using loc() function on the 'ords_prods_merged'
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## If- statement with for-loops

# %%
df_ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
#Creating a loop for the 'order_day_of_week' values
result = []

for value in df_ords_prods_merged["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Task Exercise

# %% [markdown]
# ### Creating new column 'Busiest days'

# %%
df_ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# #### Busiest days are 0 and 1 (Saturday and Sunday), least busy days are 3 and 4 (Tuesday and Wednesday)

# %%
#Creating a loop for the 'order_day_of_week' values
days = []

for value in df_ords_prods_merged['order_day_of_week']:
  if value == 0 or value == 1:
    days.append('Busiest days')
  elif value == 3 or value == 4:
    days.append('Slowest days')
  else:
    days.append('Regularly busy')

# %%
#Creating the column 'busiest_days' and adding to the dataframe
df_ords_prods_merged['busiest_days'] = days

# %%
#Checking value count
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest_days, dtype: int64

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 20)

# %% [markdown]
# #### Sum of counts of values equal to total number of rows in the dataframe 'df_ords_prods_merged'

# %% [markdown]
# ### Creating new column 'busiest_period_of_day'

# %%
#Checking the frequency of the values in 'order_hour_of_day'
count_of_orders = df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)

# %%
count_of_orders
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
#Searching for percentile of the count of values
list = list(df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False).quantile([0.75, 0.5, 0.25]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22576\359413430.py in <module>
# ----> 1 list = list(df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False).quantile([0.75, 0.5, 0.25]))
#
# TypeError: 'list' object is not callable

# %%
list
# Out:
# [2556034.5, 1117230.5, 272562.0]

# %% [markdown]
# ##### Based on the percentiles, we can divide the hours into 3 groups:
# ##### Group 1 (Fewest orders - Under 272562 orders): 3, 4, 2, 5, 1, 0
# ##### Group 2 (Average orders - Between 272562 and 2556034.5): 6, 23, 22, 21, 7, 20,19,18,8,17,9,16
# ##### Group 3 (Most orders - Over 2556034.5): 12,13,15,14,11,10

# %%
#Creating a loop for 'order_hour_of_day' values
hours = []

for value in df_ords_prods_merged['order_hour_of_day']:
  if value in [10, 11, 14, 15, 13, 12]:
    hours.append('Most orders')
  elif value in [0, 1, 5, 2, 4, 3]:
    hours.append('Fewest orders')
  else:
    hours.append('Average orders')

# %%
#Adding the column 'busiest_period_of_day' to the dataframe
df_ords_prods_merged['busiest_period_of_day'] = hours

# %%
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  new_customer  \
# 0                  2                  8                     NaN          True
# 1                  3                  7                    15.0         False
# 2                  3                 12                    21.0         False
# 3                  4                  7                    29.0         False
# 4                  4                 15                    28.0         False
#
#    product_id  ...  _merge  Unnamed: 0_y product_name  aisle_id department_id  \
# ...

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       16128666
# Average orders    15679865
# Fewest orders       596328
# Name: busiest_period_of_day, dtype: int64

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 22)

# %% [markdown]
# #### The sum of counts of 'busiest_period_of_day' equals to total number of rows in dataframe 'df_ords_prods_merged'

# %%
#Exporting the dataframe in .pkl format
df_ords_prods_merged.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged_updated.pkl'))
